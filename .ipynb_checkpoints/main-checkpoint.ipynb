# %%
import requests

url = "https://datasets-server.huggingface.co/first-rows?dataset=yhavinga%2Fcnn_dailymail_dutch&config=3.0.0&split=train"

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print("Failed to retrieve data. Response code:", response.status_code)
# Out:
# {'dataset': 'yhavinga/cnn_dailymail_dutch', 'config': '3.0.0', 'split': 'train', 'features': [{'feature_idx': 0, 'name': 'article', 'type': {'dtype': 'string', '_type': 'Value'}}, {'feature_idx': 1, 'name': 'highlights', 'type': {'dtype': 'string', '_type': 'Value'}}, {'feature_idx': 2, 'name': 'id', 'type': {'dtype': 'string', '_type': 'Value'}}], 'rows': [{'row_idx': 0, 'row': {'article': 'LONDEN, Engeland (Reuters) - Harry Potter-ster Daniel Radcliffe krijgt toegang tot een gerapporteerd fortuin van £ 20 miljoen ($ 41,1 miljoen) terwijl hij maandag 18 wordt, maar hij dringt erop aan dat het geld hem niet zal betoveren. Daniel Radcliffe als Harry Potter in "Harry Potter en de Orde van de Feniks" Tot de teleurstelling van roddelcolumnisten over de hele wereld, zegt de jonge acteur dat hij geen plannen heeft om zijn geld weg te gooien op snelle auto\'s, drank en beroemdheidsfeesten. "Ik ben niet van plan om een van die mensen te zijn die, zodra ze 18 worden, plotseling een enorme sportwagencollectie of iets dergelijks kopen", vertelde hij eerder deze maand aan een Australische interviewer. "Ik denk niet dat ik bijzonder extravagant zal zijn. "De dingen die ik graag koop zijn dingen die ongeveer 10 pond kosten - boeken en cd\'s en dvd\'s." Op 18, zal Radcliffe in staat zijn om te gokken in een casino, kopen een drankje in een pub of zie de horror film Hostel: Part II, momenteel zes plaatsen onder zijn nummer een film op de UK box office chart. Details van hoe hij zijn mijlpaal verjaardag zal markeren zijn onder wraps. Zijn agent en publicist had geen commentaar op zijn plannen. Ik zal zeker een soort van partij, zei hij in een interview. Hopelijk zal niemand van jullie erover lezen. Radcliffe\'s inkomsten uit de eerste vijf Potter-films zijn vastgehouden in een trustfonds dat hij niet heeft kunnen aanraken. Ondanks zijn groeiende roem en rijkdom, zegt de acteur dat hij zijn voeten stevig op de grond houdt. "Mensen zijn altijd op zoek om te zeggen \'kid star gaat van de rails\',\'vertelde hij verslaggevers vorige maand. "Maar ik probeer heel hard om niet op die manier te gaan omdat het te gemakkelijk voor hen zou zijn." Zijn laatste uitje als de jongen tovenaar in Harry Potter en de Orde van de Feniks is het breken van records aan beide zijden van de Atlantische Oceaan en hij zal reprise de rol in de laatste twee films.  Bekijk I-Reporter geeft haar recensie van Potter\'s nieuwste » Er is echter leven buiten Potter. De Londenaar heeft een tv-film gefilmd met de naam "My Boy Jack", over auteur Rudyard Kipling en zijn zoon, die later dit jaar wordt vrijgegeven. Hij zal ook verschijnen in "December Boys", een Australische film over vier jongens die een weeshuis te ontsnappen. Eerder dit jaar maakte hij zijn debuut als een gemartelde tiener in Peter Shaffers Equus. Ondertussen staat hij klaar voor nog meer media-onderzoek nu hij legaal een volwassene is: "Ik denk gewoon dat ik meer een soort eerlijk spel zal zijn", vertelde hij aan Reuters. E-mail naar een vriend Copyright 2007 Reuters Alle rechten voorbehouden.Dit materiaal mag niet worden gepubliceerd, uitgezonden, herschreven of herverdeeld.', 'highlights': "Harry Potter-ster Daniel Radcliffe krijgt £ 20M fortuin als hij maandag 18 wordt\nJonge acteur zegt dat hij geen plannen heeft om zijn geld weg te gooien.\nRadcliffe's inkomsten uit de eerste vijf Potter-films zijn in een trustfonds gehouden.", 'id': '42c027e4ff9730fbb3de84c1af0d2c506e41c3e4'}, 'truncated_cells': []}, {'row_idx': 1, 'row': {'article': 'Noot van de redactie: In onze Behind the Scenes-serie delen CNN-correspondenten hun ervaringen bij het verslaan van nieuws en analyseren ze de verhalen achter de gebeurtenissen. Hier, Soledad O\'Brien neemt gebruikers in een gevangenis waar veel van de gevangenen zijn geestelijk ziek. Een gevangene gehuisvest op de "vergeten vloer," waar veel geesteszieke gevangenen zijn gehuisvest in Miami voor het proces. MIAMI, Florida (CNN) - De negende verdieping van de Miami-Dade voorlopi ...

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PRATHAM\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize

# # Tokenize the article field
# for row in data['rows']:
#     article = row['row']['article']
#     article_tokens = word_tokenize(article)
#     print(article_tokens)
    
# # Tokenize the highlights field
# for row in data['rows']:
#     highlights = row['row']['highlights']
#     highlights_tokens = word_tokenize(highlights)
#     print(highlights_tokens)
    
article = "The first ever iPhone was launched in 2007 by Apple Inc. The iPhone revolutionized the mobile phone industry and brought a new level of technology to the market. The iPhone had a large impact on the way people use their phones and changed the way people communicate with each other. Today, there are several different models of iPhones available with even more advanced features and capabilities"
article_tokens = word_tokenize(article)
print(article_tokens)
# Out:
# ['The', 'first', 'ever', 'iPhone', 'was', 'launched', 'in', '2007', 'by', 'Apple', 'Inc', '.', 'The', 'iPhone', 'revolutionized', 'the', 'mobile', 'phone', 'industry', 'and', 'brought', 'a', 'new', 'level', 'of', 'technology', 'to', 'the', 'market', '.', 'The', 'iPhone', 'had', 'a', 'large', 'impact', 'on', 'the', 'way', 'people', 'use', 'their', 'phones', 'and', 'changed', 'the', 'way', 'people', 'communicate', 'with', 'each', 'other', '.', 'Today', ',', 'there', 'are', 'several', 'different', 'models', 'of', 'iPhones', 'available', 'with', 'even', 'more', 'advanced', 'features', 'and', 'capabilities']

# %%
#lowering the case :

lower_article_tokens = [token.lower() for token in article_tokens]
# lower_highlights_tokens = [token.lower() for token in highlights_tokens]

# %%
#remove punctuations:

import string

def remove_punctuation(text):
    # create a translation table to remove punctuation and special characters
    table = str.maketrans('', '', string.punctuation)
    
    # remove the punctuation and special characters from the text
    cleaned_text = text.translate(table)
    
    return cleaned_text

# remove punctuation and special characters from article_tokens
p_removed_article_tokens = [remove_punctuation(token) for token in lower_article_tokens]

# remove punctuation and special characters from highlights_tokens
# p_removed_highlights_tokens = [remove_punctuation(token) for token in lower_highlights_tokens]

# %%
#removing stopwords

from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))

filtered_article_tokens = [word for word in p_removed_article_tokens if word.lower() not in stop_words]
# filtered_highlights_tokens = [word for word in p_removed_highlights_tokens if word.lower() not in stop_words]

# %%
#stemming

from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

article_stemmed_words = [stemmer.stem(word) for word in filtered_article_tokens]
# highlights_stemmed_words = [stemmer.stem(word) for word in filtered_article_tokens]

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

article_lemmatized_words = [lemmatizer.lemmatize(word) for word in article_stemmed_words]
# highlights_lemmatized_words = [lemmatizer.lemmatize(word) for word in highlights_stemmed_words]

# %%
# from nltk.wsd import lesk
# from nltk.corpus import wordnet

# def disambiguate_word(word, tokens):
#     return lesk(tokens, word, pos=wordnet.VERB)

# # Disambiguate article tokens
# disambiguated_article_tokens = [disambiguate_word(token, article_lemmatized_words) for token in article_tokens]

# # Disambiguate highlights tokens
# disambiguated_highlights_tokens = [disambiguate_word(token, highlights_lemmatized_words) for token in highlights_tokens]

# %%
# from nltk.wsd import lesk

# for word in article_tokens:
#     sense = lesk(article, word)
#     print(f"Word: {word}, Sense: {sense}")
    
# for word in highlights_tokens:
#     sense = lesk(highlights, word)
#     print(f"Word: {word}, Sense: {sense}")

# %%
import nltk
from nltk.corpus import wordnet

def adapted_lesk(word, context, pos=None):
    word = word.lower()
    context = [w.lower() for w in context]
    synsets = wordnet.synsets(word)
    if pos is None:
        signatures = synsets
    else:
        signatures = [synset for synset in synsets if synset.pos() == pos]
    best_sense = None
    max_overlap = 0
    for signature in signatures:
        definition = signature.definition().split()
        definition = [w.lower() for w in definition if w.isalpha()]
        definition_synonyms = []
        for syn in signature.lemmas():
            definition_synonyms.append(syn.name().lower())
        definition_synonyms.append(signature.lemma_names()[0].lower())
        overlap = set(definition).intersection(context)
        if len(overlap) > max_overlap:
            max_overlap = len(overlap)
            best_sense = signature
        if len(overlap) == max_overlap:
            definition_len = len(definition)
            if best_sense:
                best_sense_len = len(best_sense.definition().split())
                if definition_len < best_sense_len:
                    best_sense = signature
            else:
                best_sense = signature
    return best_sense


disambiguated_article_tokens = []
for token in article_tokens:
    sense = adapted_lesk(token, article_lemmatized_words)
    if sense is not None:
        disambiguated_article_tokens.append(sense)

# disambiguated_highlights_tokens = []
# for token in highlights_tokens:
#     sense = adapted_lesk(token, highlights_lemmatized_words)
#     if sense is not None:
#         disambiguated_highlights_tokens.append(sense)

article_sense = []
for word in article_lemmatized_words:
    sense = adapted_lesk(word, article)
    if sense is not None:
        article_sense.append(sense)
    
# highlights_sense = []
# for word in highlights_lemmatized_words:
#     sense = adapted_lesk(word, highlights)
#     if sense is not None:
#         highlights_sense.append(sense)

# %%
article_sense_tokens = [str(word.lemmas()[0].name().lower()) for word in article_sense]

# %%
highlights_sense_tokens = []
for sense in highlights_sense:
    highlights_sense_tokens.append(sense.lemmas()[0].name().lower())

# %%
for sense in article_sense:
    print(type(sense))
# Out:
# <class 'str'>

# %%
article_sense
# Out:
# [Synset('first.n.02'),
#  Synset('ever.r.03'),
#  Synset('launch.v.03'),
#  Synset('iraqi_national_congress.n.01'),
#  Synset('rotation.n.03'),
#  Synset('phone.n.02'),
#  Synset('lend.v.01'),
#  Synset('newfangled.s.01'),
#  Synset('charge.v.17'),
#  Synset('market.v.03'),
#  Synset('impact.n.02'),
#  Synset('way.n.05'),
#  Synset('use.n.03'),
#  Synset('phone.n.02'),
#  Synset('chang_jiang.n.01'),
#  Synset('way.n.05'),
#  Synset('nowadays.r.01'),
#  Synset('discerp.v.02'),
#  Synset('differ.v.01'),
#  Synset('model.n.02'),
#  Synset('avail.n.01'),
#  Synset('tied.s.05')]

# %%
# FOR ARTICLE

import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer

def get_wordnet_pos(pos_tag):
    if pos_tag[1].startswith('J'):
        return (pos_tag[0], wn.ADJ)
    elif pos_tag[1].startswith('V'):
        return (pos_tag[0], wn.VERB)
    elif pos_tag[1].startswith('N'):
        return (pos_tag[0], wn.NOUN)
    elif pos_tag[1].startswith('R'):
        return (pos_tag[0], wn.ADV)
    else:
        return (pos_tag[0], wn.NOUN)

def preprocess(article):
    # Named Entity Recognition
    entities = nltk.ne_chunk(nltk.pos_tag(word_tokenize(article)))
    entity_list = []
    for entity in entities:
        if hasattr(entity, 'label'):
            entity_list.append((entity.label(), " ".join(c[0] for c in entity.leaves())))
    # Frequency Distribution
    words = nltk.word_tokenize(article)
    fdist = nltk.FreqDist(words)
    # Taxonomy
    tagged_words = pos_tag(words)
    wnl = WordNetLemmatizer()
    lemmatized_words = [wnl.lemmatize(*get_wordnet_pos(tagged_word)) for tagged_word in tagged_words]
    # θd
    theta_d = {}
    for word, pos in tagged_words:
        synonyms = wn.synsets(word, pos=wn.NOUN if pos.startswith("N") else (wn.ADJ if pos.startswith("J") else (wn.VERB if pos.startswith("V") else (wn.ADV if pos.startswith("R") else wn.NOUN))))
        theta_d[word] = set(syn.lemmas()[0].name() for syn in synonyms)
    # θf
    theta_f = {}
    for word, pos in tagged_words:
        theta_f[word] = fdist[word] / float(len(words))
    return (entities, entity_list, fdist, lemmatized_words, theta_d, theta_f)


article_data = preprocess(article)


named_entities = article_data[1]
Frequency_Distribution = article_data[2].most_common(10)
Taxonomy = article_data[3]
fi_d = article_data[4]
fi_f = article_data[5]

# Print Named Entities
print("Named Entities:", article_data[1])
# Print Frequency Distribution
print("\nFrequency Distribution:", article_data[2].most_common(10))
# Print Taxonomy
print("\nTaxonomy:", article_data[3])
# Print θd
print("\nθd:", article_data[4])
# Print θf
print("\nθf:", article_data[5])
# Out:
# Named Entities: [('ORGANIZATION', 'iPhone'), ('PERSON', 'Apple Inc'), ('ORGANIZATION', 'iPhone'), ('ORGANIZATION', 'iPhone'), ('ORGANIZATION', 'iPhones')]
#
# Frequency Distribution: [('the', 4), ('The', 3), ('iPhone', 3), ('.', 3), ('and', 3), ('a', 2), ('of', 2), ('way', 2), ('people', 2), ('with', 2)]
#
# Taxonomy: ['The', 'first', 'ever', 'iPhone', 'be', 'launch', 'in', '2007', 'by', 'Apple', 'Inc', '.', 'The', 'iPhone', 'revolutionize', 'the', 'mobile', 'phone', 'industry', 'and', 'bring', 'a', 'new', 'level', 'of', 'technology', 'to', 'the', 'market', '.', 'The', 'iPhone', 'have', 'a', 'large', 'impact', 'on', 'the', 'way', 'people', 'use', 'their', 'phone', 'and', 'change', 'the', 'way', 'people', 'communicate', 'with', 'each', 'other', '.', 'Today', ',', 'there', 'be', 'several', 'different', 'model', 'of', 'iPhones', 'available', 'with', 'even', 'more', 'advanced', 'feature', 'and', 'capability']
#
# θd: {'The': set(), 'first': {'first', 'beginning', 'inaugural'}, 'ever': {'ever', 'always'}, 'iPhone': set(), 'was': {'be', 'constitute', 'cost', 'exist', 'equal', 'embody'}, 'launched': {'plunge', 'launch', 'establish'}, 'in': {'indium', 'Indiana', 'inch'}, '2007': set(), 'by': set(), 'Apple': {'apple'}, 'Inc': {'Iraqi_National_Congress'}, '.': set(), 'revolutionized': {'revolutionize'}, 'the': set(), 'mobile': {'mobile', 'fluid'}, 'phone': {'earphone', 'phone', 'telephone'}, 'industry': {'industry', 'diligence'}, 'and': set(), 'brought': {'lend', 'fetch', 'bring', 'institute'}, 'a': {'vitamin_A', 'angstrom', 'adenine', 'A', 'ampere', 'deoxyadenosine_monophosphate'}, 'new': {'new', 'raw', 'newfangled', 'fresh', 'Modern', 'New'}, 'level': {'grade', 'degree', 'horizontal_surface', 'level', 'floor'}, 'of': set(), 'technology': {'engineering', 'technology'}, 'to': set(), 'market': {'grocery_store', 'marketplace', 'market'}, 'had': {'suffer', 'own', 'get', 'accept', 'consume', 'hold', 'have', 'induce', 'experience', 'receive', 'take', 'give_birth'}, 'large': {'large', 'bombastic', 'big'}, 'impact': {'shock', 'impact', 'impingement'}, 'on': set(), 'way': {'manner', 'means', 'room', 'way', 'direction'}, 'people': {'people', 'multitude', 'citizenry'}, 'use': {'practice', 'use'}, 'their': set(), 'phones': {'earphone', 'phone', 'telephone'}, 'changed': {'switch', 'change', 'exchange', 'transfer', 'deepen'}, 'communicate': {'communicate', 'convey', 'commune'}, 'with': set(), 'each': set(), 'other': {'other', 'early'}, 'Today': {'today'}, ',': set(), 'there': {'there'}, 'are': {'be', 'constitute', 'cost', 'exist', 'equal', 'embody'}, 'several': {'several', 'respective'}, 'different': {'different', 'unlike'}, 'models': {'exemplar', 'mannequin', 'model'}, 'iPhones': set(), 'available': {'available'}, 'even': {'even'}, 'more': {'more'}, 'advanced': {'advanced', 'advance'}, 'features': {'feature_of_speech', 'feature'}, 'capabilities': {'capability'}}
#
# θf: {'The': 0.04285714285714286, 'first': 0.014285714285714285, 'ever': 0.014285714285714285, 'iPhone': 0.04285714285714286, 'was': 0.014285714285714285, 'launched': 0.014285714285714285, 'in': 0.014285714285714285, '2007': 0.014285714285714285, 'by': 0.014285714285714285, 'Apple': 0.014285714285714285, 'Inc': 0.014285714285714285, '.': 0.04285714285714286, 'revolutionized': 0.014285714285714285, 'the': 0.05714285714285714, 'mobile': 0.014285714285714285, 'phone': 0.014285714285714285, 'industry': 0.014285714285714285, 'and': 0.04285714285714286, 'brought': 0.014285714285714285, 'a': 0.02857142857142857, 'new': 0.014285714285714285, 'level': 0.014285714285714285, 'of': 0.02857142857142857, 'technology': 0.014285714285714285, 'to': 0.014285714285714285, 'market': 0.014285714285714285, 'had': 0.014285714285714285, 'large': 0.014285714285714285, 'impact': 0.014285714285714285, 'on': 0.014285714285714285, 'way': 0.02857142857142857, 'people': 0.02857142857142857, 'use': 0.014285714285714285, 'their': 0.014285714285714285, 'phones': 0.014285714285714285, 'changed': 0.014285714285714285, 'communicate': 0.014285714285714285, 'with': 0.02857142857142857, 'each': 0.014285714285714285, 'other': 0.014285714285714285, 'Today': 0.014285714285714285, ',': 0.014285714285714285, 'there': 0.014285714285714285, 'are': 0.014285714285714285, 'several': 0.014285714285714285, 'different': 0.014285714285714285, 'models': 0.014285714285714285, 'iPhones': 0.014285714285714285, 'available': 0.014285714285714285, 'even': 0.014285714285714285, 'more': 0.014285714285714285, 'advanced': 0.014285714285714285, 'features': 0.014285714285714285, 'capabilities': 0.014285714285714285}

# %%
# FOR HIGHLGHTS

import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer

def get_wordnet_pos(pos_tag):
    if pos_tag[1].startswith('J'):
        return (pos_tag[0], wn.ADJ)
    elif pos_tag[1].startswith('V'):
        return (pos_tag[0], wn.VERB)
    elif pos_tag[1].startswith('N'):
        return (pos_tag[0], wn.NOUN)
    elif pos_tag[1].startswith('R'):
        return (pos_tag[0], wn.ADV)
    else:
        return (pos_tag[0], wn.NOUN)

def preprocess(article):
    # Named Entity Recognition
    entities = nltk.ne_chunk(nltk.pos_tag(word_tokenize(article)))
    entity_list = []
    for entity in entities:
        if hasattr(entity, 'label'):
            entity_list.append((entity.label(), " ".join(c[0] for c in entity.leaves())))
    # Frequency Distribution
    words = nltk.word_tokenize(article)
    fdist = nltk.FreqDist(words)
    # Taxonomy
    tagged_words = pos_tag(words)
    wnl = WordNetLemmatizer()
    lemmatized_words = [wnl.lemmatize(*get_wordnet_pos(tagged_word)) for tagged_word in tagged_words]
    # θd
    theta_d = {}
    for word, pos in tagged_words:
        synonyms = wn.synsets(word, pos=wn.NOUN if pos.startswith("N") else (wn.ADJ if pos.startswith("J") else (wn.VERB if pos.startswith("V") else (wn.ADV if pos.startswith("R") else wn.NOUN))))
        theta_d[word] = set(syn.lemmas()[0].name() for syn in synonyms)
    # θf
    theta_f = {}
    for word, pos in tagged_words:
        theta_f[word] = fdist[word] / float(len(words))
    return (entities, entity_list, fdist, lemmatized_words, theta_d, theta_f)


highlights_data = preprocess(highlights)


# Print Named Entities
print("Named Entities:", highlights_data[1])
# Print Frequency Distribution
print("\nFrequency Distribution:", highlights_data[2].most_common(10))
# Print Taxonomy
print("\nTaxonomy:", highlights_data[3])
# Print θd
print("\nθd:", highlights_data[4])
# Print θf
print("\nθf:", highlights_data[5])
# Out:
# Named Entities: [('PERSON', 'Julia'), ('PERSON', 'Vakulenko'), ('ORGANIZATION', 'WTA Tour'), ('ORGANIZATION', 'Bell'), ('PERSON', 'De Oekraïense'), ('PERSON', 'Lindsay Davenport'), ('PERSON', 'Julie Ditty'), ('PERSON', 'Voormalige'), ('GPE', 'Russische'), ('PERSON', 'Vera Zvonareva')]
#
# Frequency Distribution: [('.', 4), ('de', 2), ('Davenport', 2), ('Julia', 1), ('Vakulenko', 1), ('heeft', 1), ('haar', 1), ('eerste', 1), ('finale', 1), ('bereikt', 1)]
#
# Taxonomy: ['Julia', 'Vakulenko', 'heeft', 'haar', 'eerste', 'finale', 'bereikt', 'op', 'de', 'WTA', 'Tour', 'bij', 'Bell', 'Challenge', '.', 'De', 'Oekraïense', 'derde', 'zaad', 'zal', 'worden', 'geconfronteerd', 'Lindsay', 'Davenport', 'na', 'het', 'verslaan', 'van', 'Julie', 'Ditty', '.', 'Voormalige', 'wereld', 'No', '.', '1', 'Davenport', 'versloeg', 'de', 'Russische', 'tweede', 'reek', 'Vera', 'Zvonareva', '.']
#
# θd: {'Julia': set(), 'Vakulenko': set(), 'heeft': set(), 'haar': set(), 'eerste': set(), 'finale': set(), 'bereikt': set(), 'op': set(), 'de': {'Delaware'}, 'WTA': set(), 'Tour': {'enlistment', 'go', 'tour'}, 'bij': set(), 'Bell': {'Bell', 'doorbell', 'bell', 'chime'}, 'Challenge': {'challenge'}, '.': set(), 'De': {'Delaware'}, 'Oekraïense': set(), 'derde': set(), 'zaad': set(), 'zal': set(), 'worden': set(), 'geconfronteerd': set(), 'Lindsay': {'Lindsay'}, 'Davenport': {'davenport', 'Davenport'}, 'na': {'sodium'}, 'het': set(), 'verslaan': set(), 'van': {'avant-garde', 'vanguard', 'van'}, 'Julie': set(), 'Ditty': {'ditty'}, 'Voormalige': set(), 'wereld': set(), 'No': {'no', 'nobelium'}, '1': {'one'}, 'versloeg': set(), 'Russische': set(), 'tweede': set(), 'reeks': {'malodor'}, 'Vera': set(), 'Zvonareva': set()}
#
# θf: {'Julia': 0.022222222222222223, 'Vakulenko': 0.022222222222222223, 'heeft': 0.022222222222222223, 'haar': 0.022222222222222223, 'eerste': 0.022222222222222223, 'finale': 0.022222222222222223, 'bereikt': 0.022222222222222223, 'op': 0.022222222222222223, 'de': 0.044444444444444446, 'WTA': 0.022222222222222223, 'Tour': 0.022222222222222223, 'bij': 0.022222222222222223, 'Bell': 0.022222222222222223, 'Challenge': 0.022222222222222223, '.': 0.08888888888888889, 'De': 0.022222222222222223, 'Oekraïense': 0.022222222222222223, 'derde': 0.022222222222222223, 'zaad': 0.022222222222222223, 'zal': 0.022222222222222223, 'worden': 0.022222222222222223, 'geconfronteerd': 0.022222222222222223, 'Lindsay': 0.022222222222222223, 'Davenport': 0.044444444444444446, 'na': 0.022222222222222223, 'het': 0.022222222222222223, 'verslaan': 0.022222222222222223, 'van': 0.022222222222222223, 'Julie': 0.022222222222222223, 'Ditty': 0.022222222222222223, 'Voormalige': 0.022222222222222223, 'wereld': 0.022222222222222223, 'No': 0.022222222222222223, '1': 0.022222222222222223, 'versloeg': 0.022222222222222223, 'Russische': 0.022222222222222223, 'tweede': 0.022222222222222223, 'reeks': 0.022222222222222223, 'Vera': 0.022222222222222223, 'Zvonareva': 0.022222222222222223}

# %%
Frequency_Distribution
# Out:
# [('the', 4),
#  ('The', 3),
#  ('iPhone', 3),
#  ('.', 3),
#  ('and', 3),
#  ('a', 2),
#  ('of', 2),
#  ('way', 2),
#  ('people', 2),
#  ('with', 2)]

# %%
text = article
E = named_entities
F = Frequency_Distribution
T = Taxonomy
θf = 2
θd = 3

from nltk.corpus import wordnet

def Level_driven_text_Generalization(text, wsdText, F, T, θd, θf):
    genText = text
    tokens = text.split()
    for i, token in enumerate(tokens):
        ftoken = next((f[1] for f in F if f[0] == token), 0)
        if ftoken <= θf:
            if i >= len(wsdText):
                break

            c = wsdText[i]
            synsets = wordnet._synset_from_pos_and_offset(c.pos(), c.offset())
            Pc = synsets.hypernym_paths()
            dc = synsets.max_depth()
            fc = next((f[1] for f in F if f[0] == synsets.lemmas()[0].name()), 0)
            for path in Pc:
                for c in path:
                    dc = c.max_depth()
                    fc = next((f[1] for f in F if f[0] == c.lemmas()[0].name()), 0)
                    if fc >= θf or dc <= θd:
                        break
                if fc >= θf or dc <= θd:
                    break
            if c.lemmas()[0].name() != token:
                genText = genText.replace(token, c.lemmas()[0].name())
                F = [(f[0], f[1]-1) if f[0] == token else f for f in F]
                F = [(f[0], f[1]+1) if f[0] == c.lemmas()[0].name() else f for f in F]
    return genText


def Named_entities_driven_text_Generalization(text, E, F, θf):
    genText = text
    for namedEntity, entity in E:
        if next((f[1] for f in F if f[0] == entity), 0) < θf:
            genText = genText.replace(entity, namedEntity)
    return genText

def WSD_Based_Combination_of_NEG_and_LG(text, wsdText, E, F, T, θf, θd):
    genText = Named_entities_driven_text_Generalization(text, E, F, θf)
    genText = Level_driven_text_Generalization(genText, wsdText, F, T, θd, θf)
    return genText

result = WSD_Based_Combination_of_NEG_and_LG(text, article_sense, E, F, T, θf, θd)
print(result)
# Out:
# The move move iPhone entity entity chentitynge entityfentityngled move entityct The iPhone entity the entity entity chentityngedustry entitynd differ entity entity tied of technology to the mentityrket. The iPhone hentityd entity lentityrge impentityct on the wentityy people use their entitys entitynd chentitynged the wentityy people communicentityte with eentitych other. Todentityy, there entityre smoveentityl different models of ORGANIZATION entityventityilentityble with even more entitydventitynced feentitytures entitynd centitypentitybilities
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_7232\2697635736.py:20: DeprecationWarning:
#   Function _synset_from_pos_and_offset() has been deprecated.  Use
#   public method synset_from_pos_and_offset() instead
#   synsets = wordnet._synset_from_pos_and_offset(c.pos(), c.offset())

# %%
def Level_driven_text_Generalization(text, wsdText, F, T, θd, θf):
    genText = text
    tokens = text.split()
    for i, token in enumerate(tokens):
        if i >= len(wsdText):
            break
        c = wsdText[i]
        synsets = wordnet._synset_from_pos_and_offset(c.pos(), c.offset())
        Pc = synsets.hypernym_paths()
        dc = synsets.max_depth()
        fc = next((f[1] for f in F if f[0] == synsets.lemmas()[0].name()), 0)
        for path in Pc:
            for c in path:
                dc = c.max_depth()
                fc = next((f[1] for f in F if f[0] == c.lemmas()[0].name()), 0)
                if fc >= θf or dc <= θd:
                    break
            if fc >= θf or dc <= θd:
                break
        if c.lemmas()[0].name() != token:
            genText = genText.replace(token, c.lemmas()[0].name())
            F = [(f[0], f[1]-1) if f[0] == token else f for f in F]
            F = [(f[0], f[1]+1) if f[0] == c.lemmas()[0].name() else f for f in F]
    return genText

def Named_entities_driven_text_Generalization(text, E, F, θf):
    genText = text
    for namedEntity, entity in E:
        if next((f[1] for f in F if f[0] == entity), 0) < θf:
            genText = genText.replace(namedEntity, entity)
    return genText

def WSD_Based_Combination_of_NEG_and_LG(text, wsdText, E, F, T, θf, θd):
    genText = Named_entities_driven_text_Generalization(text, E, F, θf)
    genText = Level_driven_text_Generalization(genText, wsdText, F, T, θd, θf)
    return genText

result = WSD_Based_Combination_of_NEG_and_LG(text, article_sense, E, F, T, θf, θd)
print(result)
# Out:
# entity move move entity entity entity chentitynge tiedfentityngled move entityct entity entity entity entity entity entity nowentitydentityys chentityngedustry differ entity entity tied level of technology to entity mentityrket. entity entity hentityd entity lentityrge impentityct on entity wentityy people use entityir nowentitydentityyss differ chentitynged entity wentityy people communicentityte with eentitych oentityr. Todentityy, entityre entityre smoveentityl different models of entitys entityventityilentityble with even more entitydventitynced feentitytures differ centitypentitybilities
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_7232\929123280.py:8: DeprecationWarning:
#   Function _synset_from_pos_and_offset() has been deprecated.  Use
#   public method synset_from_pos_and_offset() instead
#   synsets = wordnet._synset_from_pos_and_offset(c.pos(), c.offset())

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.probability import FreqDist
from nltk.stem import PorterStemmer
from nltk.cluster.util import cosine_distance
import numpy as np

stop_words = set(stopwords.words("english"))

def summarize(text, ratio=0.2):
    # Preprocessing the text
    text = text.lower()
    text = word_tokenize(text)
    text = [word for word in text if word.isalpha()]
    text = [word for word in text if word not in stop_words]
    stemmer = PorterStemmer()
    text = [stemmer.stem(word) for word in text]
    
    # Join the processed words back into sentences
    sentences = " ".join(text)
    sentences = sent_tokenize(sentences)
    
    n = len(sentences)
    freq = FreqDist(text)
    tf = np.array([[freq[sentence.split()[i]] for i in range(len(sentence.split()))] for sentence in sentences])
    idf = np.log(n / (sum(sentence.split().count(word) for sentence in sentences) + 1))


    tf_idf = tf * idf
    # Calculating similarity score between sentences
    similarity = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            if i != j:
                similarity[i][j] = cosine_distance(tf_idf[i], tf_idf[j])

    # Applying TextRank algorithm
    score = np.zeros((n,))
    for i in range(n):
        score[i] = sum(similarity[i]) / (n-1)

    # Selecting top sentences as summary
    ranked_sentences = sorted(((score[i], s) for i, s in enumerate(sentences)), reverse=True)
    top_sentences = int(ratio * n)
    summary = " ".join([ranked_sentences[i][1] for i in range(top_sentences)])

    return summary

print(summarize(result))
# Out:
# C:\Users\PRATHAM\AppData\Local\Temp\ipykernel_7232\2763472866.py:41: RuntimeWarning: invalid value encountered in double_scalars
#   score[i] = sum(similarity[i]) / (n-1)
